# %% [markdown]
# # **Contar palabras con Map Reduce**
#
# El siguiente código implementa un ejemplo de contar palabras utilizando Map Reduce, una librería de multiprocesamiento para Python, Google Drive, y un conjunto de datos de la librería pública de Seattle.
#
# Este código fue originalmente publicado en https://github.com/ChemaSarmiento/Big_Data_UP
#
# El conjunto de datos utilizado está disponible en https://data.seattle.gov/Community/Checkouts-by-Title/tmmm-ytt6

# %%
'''
Primeramente importamos las librerías necesarias para poder ejecutar el código
'''

# Paralelismo, concurrencia y aprovechar al maximo todos los procesadores en 
#   una maquina
import multiprocessing as mp
# Usar funcionalidades dependientes del sistema operativo
import os
# Acceso aleatoria a lineas de texto; permite obtener cualquier línea de un 
#   archivo fuente Python
import linecache
# Permite que al llamar a un objeto este se comporte como funcion
from functools import partial

# %%
'''
Antes de comenzar, revisamos el número de procesadores a los que tenemos acceso
'''
print("No. de Procesadores: {}".format(mp.cpu_count()))
# Out:
# No. de Procesadores: 2

# %% [markdown]
# **Primeramente hay que hacer que Google Colab pueda acceder a Google Drive**
#
# Para ello, hay que seguir los siguiente pasos:
#
# 1. Hacer clic en la parte izquierda de la interfaz de Google Colab, en el símbolo de carpeta para desplegar el menú de Archivos
#
# 2. Hacer clic en el icono de la carpeta con el símbolo de Google Drive
#
# 3. Permitir a Google Colab acceder a Google Drive
#
# 4. Verificar que tenemos acceso a Google Drive al corroborar que podemos visualizar nuestros archivos

# %% [markdown]
# **Recomendable**
#
# Se recomienda generar una carpeta dedicada para la práctica
#
# Pasos a seguir:
#
# 1. Ubicar la carpeta denominada MyDrive
#
# 2. Colocando el cursor sobre la carpeta, hacer clic sobre los tres puntos que se visualizan en la parte derecha
#
# 3. Dar clic sobre nueva carpeta
#
# 4. Dar nombre a la nueva carpeta, tal como "BigDataExercices"
#
# 5. En esta carpeta, almacenaremos el conjunto de datos que hemos descargado de Seattle

# %%
'''
Ahora, tenemos que hacer disponible el conjunto de datos con los que vamos a 
trabajar.

Para ello, copiaremos el conjunto de datos desde donde los tenemos almacenados
a un repositorio temporal para que Google Colab los pueda acceder

Si no pudimos descargar los datos desde la página principal, podemos 
clonar/copiar el conjunto de datos desde el siguiente enlace:

https://drive.google.com/drive/folders/1JKe-FxNJqM2RabYRvm8p6Q_Vi7geBBuT?usp=share_link

'''

# este comando nos ayuda a copiar el archivo a la máquina local de Colab
#   Importante, necesitamos iniciar el comando con el signo de exclamacion y 
#     finalizarlo con un espacio y el punto final

# !cp /content/drive/MyDrive/BigDataExercices/checkouts_seattle.zip .

# %%
'''
Si copiamos/clonamos los datos desde el enlace de Google Drive, entonces tenemos
que descomprimir el archivo para obtener el CSV
'''

# !unzip /content/checkouts_seattle.zip
# Out:
# Archive:  /content/checkouts_seattle.zip
#   inflating: checkouts-by-title.csv
#   inflating: __MACOSX/._checkouts-by-title.csv

# %%
'''
Verificamos que el conjunto de datos se encuentre en la maquina local de Colab
'''

# the ls command shows a list of all the files in a directory
# -l is an option to show the list in large format
# -h is an option to show the sizes of the files in 'human readable' format
# !ls -lh
# Out:
# total 12G
# -rw-r--r-- 1 root root 8.9G Apr 23 19:31 checkouts-by-title.csv
# -rw------- 1 root root 2.8G Apr 29 02:21 checkouts_seattle.zip
# drwx------ 7 root root 4.0K Apr 29 02:16 drive
# drwxr-xr-x 2 root root 4.0K Apr 29 02:26 __MACOSX
# drwxr-xr-x 1 root root 4.0K Apr 27 13:35 sample_data

# %%
# echamos un vistazo a la parte final del conjunto de datos
# !tail checkouts-by-title.csv
# Out:
# Digital,OverDrive,AUDIOBOOK,2016,3,1,"Malice Domestic, Volume 4: An Anthology of Original Traditional Mystery Stories (unabridged)",,Carolyn G. Hart,"Fiction, Mystery, Short Stories","Phoenix Books, Inc.",2009
# Physical,Horizon,BOOK,2016,3,2,Minifred goes to school / Mordicai Gerstein.,,"Gerstein, Mordicai","Cats Juvenile fiction, Animals Infancy Juvenile fiction, Obedience Juvenile fiction, Schools Fiction","HarperCollins,",2009.
# Physical,Horizon,VIDEODISC,2016,3,19,"Alléluia [videorecording] / Doppelganger Releasing ; produit par Panique, Radar Films, Savage Film ; coproduit par Versus Production, One-Eyed ; scenario, Fabrice Du Welz, Vincent Tavier ; adaptation & dialogues, Romain Protat ; un film de Fabrice Du Welz.",,,"Murder Drama, Womanizers Drama, Seduction Drama, Man woman relationships Drama, Thrillers Motion pictures, Feature films, Fiction films, Horror films, Motion pictures French","Doppelganger Releasing,",[2015]
# Physical,Horizon,BOOK,2016,3,1,No-fear home improvement.,,,"Dwellings Maintenance and repair, Dwellings Remodeling, Do it yourself work","Creative Homeowner,",c2007.
# Physical,Horizon,BOOK,2016,3,1,Crazy about soccer! / written by Loris Lesynski ; illustrated by Gerry Rasmussen.,,"Lesynski, Loris","Soccer Juvenile poetry, Soccer Poetry","Annick Press,",c2012.
# Digital,Freegal,SONG,2016,3,1,Alpenglow,,Nightwish,,,
# Digital,OverDrive,EBOOK,2016,3,1,"The Welcome Home Garden Club: Twilight, Texas Series, Book 4",,Lori Wilde,"Fiction, Romance",HarperCollins Publishers Inc.,2011
# Digital,OverDrive,EBOOK,2016,3,1,Travels of Marco Polo,,Marco Polo,"Classic Literature, Fiction","Penguin Group (USA), Inc.",2013
# Digital,OverDrive,EBOOK,2016,3,2,The Childhood of Jesus: A Novel,,J. M. Coetzee,"Fiction, Literature","Penguin Group (USA), Inc.",2013
# Digital,OverDrive,EBOOK,2016,3,1,Little Bear's Little Boat,,Eve Bunting,Juvenile Fiction,Houghton Mifflin Harcourt Trade and Reference,2011

# %%
# generamos un ssubconjunto de datos con el primer 1 millon de datos
# !head -n 1000000 checkouts-by-title.csv > checkouts1M.csv

# %%
# %%time 

'''
Verificamos el tamaño total del conjunto de datos original
'''

# wc <- word count, para hacer conteo en general de caracteres
# -l hace que cuente las líneas
# !wc -l checkouts-by-title.csv
# Out:
# 42474213 checkouts-by-title.csv
# CPU times: user 215 ms, sys: 38.9 ms, total: 254 ms
# Wall time: 40.1 s

# %%
# %%time

'''
Verificamos el tamaño total del sub-conjunto de datos
'''

# !wc -l checkouts1M.csv
# Out:
# 1000000 checkouts1M.csv
# CPU times: user 11.7 ms, sys: 0 ns, total: 11.7 ms
# Wall time: 1.11 s

# %%
'''
Empezaremos a trabajar con el sub-conjunto de datos generado
'''

# asignamos una variable que contenga nuestro sub-conjunto de datos
filename = "checkouts1M.csv"

# asignamos una variable para el numero de lineas que queremos procesar
lines = 1000000

# %% [markdown]
# ## **Codificacion en forma Secuencial**

# %%
# %%time
wordCount = {}
counter = 0

for i in range(1,lines):
  ln = linecache.getline(filename, i)
  try:    
    words = ln.split(',')[6].split(" ")  
    for w in words:
      if w.upper() not in wordCount.keys():
        wordCount[w.upper()] = 0
      wordCount[w.upper()] += 1
  except Exception as e:
    print("null title {} ".format(str(e)))      
  counter += 1
  if counter % 1000000 == 0:
    print("From {start} in line {counter}".format(start=0, counter=counter))
# Out:
# CPU times: user 6.99 s, sys: 539 ms, total: 7.53 s
# Wall time: 7.59 s

# %% [markdown]
# # **Codificacion en Paralelo**

# %%
'''
Primero definimos los parametros requeridos
'''

# se define el numero de threads a ocupar, puede ser por el numero disponible
#   dictado por la maquina o se pueden definir manualmente
threads = mp.cpu_count()
threads = 4
print('No. de threads: {}'.format(threads))

# definimos el numero de partes en que dividiremos el sub-conjunto
split_size = lines // threads if lines // threads > 0 else 1
print('Tamaño de datos por cada parte: {}'.format(split_size))

# obtenemos las partes con el tamaño requerido para ser procesados de manera 
#   independiente por cada procesador
#   lines dicta donde va a iniciar cada parte del sub-conjunto de datos
parts = [x for x in range(0, lines, split_size)]
print('Partes: {}'.format(parts))
# Out:
# No. de threads: 4
# Tamaño de datos por cada parte: 250000
# Partes: [0, 250000, 500000, 750000]

# %%
'''
Definimos la funcion que nos permite procesar el conteo de palabras
'''
def countWordsInTitles(filename, chunksize, start):
  wordCount = {}
  counter = 0
  print('Comenzando desde: {}'.format(start))
  for current_line in range(start, (start+chunksize)+1):
    ln = linecache.getline(filename, current_line)
    try:
      words = ln.split(",")[6].split(" ")
      #print('Palabras encontradas en la linea: {}'.format(words))
      for w in words:
        if w.upper() not in wordCount.keys():
          wordCount[w.upper()] = 0
        wordCount[w.upper()] += 1
    except Exception as e:
      print('Lista vacia: {} '.format(str(e)))      
    counter += 1
    if counter % 1000000 == 0:
      print('Desde {} en la linea {}'.format(start, counter))
  return wordCount

# %%
# %%time

'''
En esta parte definimos el Map
'''

# distribuimos los datos de entrada a traves de procesos
pool = mp.Pool(processes=threads)

# asignamos nuestra funcion como recurrente para su procesado que tomara el
#   sub-conjunto de datos y el numero en que debe iniciar cada parte
func = partial(countWordsInTitles, filename, split_size)

# aplicamos la funcion para hacer el conteo de manera recurrente
#   aqui obtendremos los diccionarios con cada uno de los conteos de las 
#   palabras por cada procesador
res = pool.map(func, parts)

# liberamos recursos
pool.close()

# esperamos a la ejecucion de todos los procesos
pool.join()
# Out:
# Comenzando desde: 250000Comenzando desde: 0Comenzando desde: 500000
# Comenzando desde: 750000
#
# Lista vacia: list index out of range
#
# CPU times: user 224 ms, sys: 82 ms, total: 306 ms
# Wall time: 5.95 s

# %% [markdown]
# **¿Hubo mejora?**

# %%
print('Total del resultados del Mapper: {}'.format(len(res)))
# Out:
# Total del resultados del Mapper: 4

# %%
# revisamos uno de los resultados del mapper
res[0]
# Out:
# {'TITLE': 105,
#  '"EMBRACING': 1,
#  'LOVE.': 62,
#  'VOLUME': 2088,
#  '3': 1130,
#  '&': 10862,
#  '4': 771,
#  '/': 134087,
#  'STORY': 5634,
#  'AND': 42039,
#  'ART': 3359,
#  'BY': 73402,
#  'YOUKA': 1,
#  'NITTA': 2,
#  ';': 69244,
#  '[TRANSLATION': 696,
#  'PENNY': 139,
#  'HER': 638,
#  'DOLL': 69,
#  'POSSESSION': 13,
#  ':': 52872,
#  'A': 42600,
#  'ROMANCE': 239,
#  'A.S.': 15,
#  'BYATT.': 6,
#  'BOSTON': 172,
#  '"MUY': 2,
#  'BUENO': 4,
#  'THREE': 1054,
#  'GENERATIONS': 24,
#  'OF': 50208,
#  'AUTHENTIC': 96,
#  'MEXICAN': 90,
#  'FLAVOR': 52,
#  'RECIPES': 1607,
#  'QB': 4,
#  'BLITZ': 9,
#  '[TEXT': 2104,
#  'WRITTEN': 6747,
#  'STEPHANIE': 312,
#  'PETERS].': 1,
#  'MY': 3900,
#  'LEAD': 81,
#  'DOG': 851,
#  'WAS': 678,
#  'LESBIAN:': 1,
#  'MUSHING': 1,
#  'ACROSS': 165,
#  'ALASKA': 110,
#  'IN': 18448,
#  'THE': 107438,
#  'IDITAROD—THE': 1,
#  "WORLD'S": 528,
#  'MOST': 917,
#  'GRUELING': 1,
#  'RACE': 279,
#  '"BARRIO': 3,
#  'CUBA': 79,
#  '[VIDEORECORDING]': 20084,
#  'LAGUNA': 15,
#  'PRODUCTIONS': 2971,
#  'PRESENTS': 932,
#  'AN': 5708,
#  'ICAIC/FINE': 2,
#  '"QUADRIVIUM': 2,
#  'FOUR': 673,
#  'CLASSICAL': 95,
#  'LIBERAL': 34,
#  'ARTS': 253,
#  'NUMBER': 108,
#  'MORE': 1172,
#  'ABOUT': 1913,
#  'PADDINGTON': 40,
#  '[SOUND': 20827,
#  'RECORDING]': 18346,
#  'MICHAEL': 2604,
#  'BOND.': 43,
#  'MIDNIGHT': 390,
#  'THIEF': 175,
#  'LIVIA': 8,
#  'BLACKBURNE.': 2,
#  'DEATH': 1208,
#  'CAESAR': 42,
#  "HISTORY'S": 42,
#  'FAMOUS': 158,
#  'ASSASSINATION': 52,
#  'BARRY': 320,
#  'STRAUSS.': 26,
#  'TRUE': 1431,
#  'BLUE': 871,
#  'SCOUTS': 19,
#  'SUGAR': 206,
#  'MAN': 1737,
#  'SWAMP': 42,
#  'KATHI': 26,
#  'APPELT.': 4,
#  'RAIN': 290,
#  'SHADOW.': 5,
#  'SERIES': 20453,
#  '1': 1874,
#  'CREATED': 506,
#  'TONY': 474,
#  'MORPHETT': 2,
#  'JIMMY': 134,
#  'THOMSON': 31,
#  'PRODUCED': 8286,
#  'GUS': 21,
#  'HOWARD': 349,
#  'DIRECTED': 5271,
#  'SHAWN': 80,
#  'SEET': 2,
#  'FIONA': 77,
#  'BANKS': 114,
#  'AUSTRALIAN': 64,
#  'BROADCASTING': 244,
#  'CORPORATION': 487,
#  'FILM': 2661,
#  'FINANCE': 87,
#  'AUSTRALIA': 122,
#  'LTD': 41,
#  'SOUTHERN': 174,
#  'STAR': 637,
#  'ENTERTAINMENT': 2414,
#  'PRODUCTION': 4776,
#  'ASSOCIATION': 2858,
#  'WITH': 12002,
#  'SOUTH': 298,
#  'CORPORATION.': 47,
#  '"MAGIC': 75,
#  'EYE': 285,
#  'BEYOND': 487,
#  '3D': 18,
#  'IMPROVE': 77,
#  'YOUR': 5834,
#  'VISION': 191,
#  'MAGIC': 852,
#  'INC.': 333,
#  'MARC': 332,
#  'GROSSMAN': 19,
#  '[WRITERS': 76,
#  'WHY': 997,
#  'HIM?': 6,
#  'HER?:': 4,
#  'FINDING': 407,
#  'REAL': 542,
#  'LOVE': 3211,
#  'UNDERSTANDING': 298,
#  'PERSONALITY': 72,
#  'TYPE': 58,
#  'DAWN': 264,
#  'LAND': 446,
#  'JOSEPH': 544,
#  'BRUCHAC': 23,
#  'ADAPTATION': 603,
#  'WILL': 918,
#  'DAVIS.': 259,
#  'NO': 1518,
#  'FLYING': 152,
#  'HOUSE': 1499,
#  'BETTY': 178,
#  'BROCK': 22,
#  'ILLUSTRATED': 11333,
#  'WALLACE': 104,
#  'TRIPP.': 20,
#  'ARCO': 3,
#  'IRIS': 87,
#  'DE': 3076,
#  'POESÍA': 3,
#  'POEMAS': 8,
#  'LAS': 137,
#  'AMÉRICAS': 2,
#  'Y': 439,
#  'ESPAÑA': 12,
#  'SELECCIÓN': 8,
#  'SERGIO': 57,
#  'ANDRICAÍN': 2,
#  'ILUSTRADO': 150,
#  'POR': 581,
#  'OLGA': 31,
#  'CUÉLLAR.': 1,
#  '¿PUEDE': 1,
#  'VOLAR': 2,
#  'UN': 250,
#  'CANGREJO?': 1,
#  'TEXTOS': 11,
#  'FLORENCIA': 2,
#  'ESSES': 1,
#  'GRACIELA': 4,
#  'REPÚN': 1,
#  'ILUSTRACIONES': 133,
#  'JAVIER': 34,
#  'PEÑA.': 15,
#  'TRAUMA': 49,
#  'PLAN': 404,
#  'CANDACE': 52,
#  'CALVERT.': 3,
#  'SUPREME': 81,
#  'MACARONI': 10,
#  'COMPANY': 809,
#  '[A': 664,
#  'NOVEL]': 360,
#  'ADRIANA': 27,
#  'TRIGIANI.': 11,
#  'LE': 332,
#  'PETIT': 13,
#  'PRINCE': 256,
#  'ANTOINE': 40,
#  'SAINT-EXUPÉRY': 9,
#  'AVEC': 252,
#  'DES': 73,
#  'AQUARELLES': 2,
#  "L'AUTEUR.": 2,
#  '"CONSENT': 2,
#  'TO': 20523,
#  'KILL:': 29,
#  'MITCH': 65,
#  'RAPP': 25,
#  'EVERY': 636,
#  'BREATH': 95,
#  'YOU': 5630,
#  'TAKE:': 11,
#  'NOVEL': 8274,
#  '"ENERGY': 9,
#  'EXPERIMENTS': 85,
#  'USING': 316,
#  'ICE': 349,
#  'CUBES': 1,
#  'CRUMB': 17,
#  'BAKING': 111,
#  'BOOK': 3248,
#  'RUBY': 127,
#  'TANDOH': 2,
#  'PHOTOGRAPHS': 1326,
#  'NATO': 3,
#  'WELTON.': 2,
#  'METERS': 3,
#  'ANTHOLOGY': 240,
#  'FUNKIFY': 1,
#  'LIFE.': 50,
#  'DON': 453,
#  'QUIXOTE': 19,
#  'MIGUEL': 60,
#  'CERVANTES': 10,
#  'TRANSLATED': 2749,
#  'EDITH': 71,
#  'GROSSMAN.': 28,
#  'WOUNDED': 25,
#  'THORN': 34,
#  'FAY': 26,
#  'SAMPSON.': 6,
#  'DISARMING': 8,
#  'NARCISSIST': 16,
#  'SURVIVING': 85,
#  'THRIVING': 33,
#  'SELF-ABSORBED': 7,
#  'WENDY': 271,
#  'T.': 388,
#  'BEHARY.': 3,
#  '"NATSUME\'S': 7,
#  'FRIENDS.': 134,
#  'YUKI': 47,
#  'MIDORIKAWA': 8,
#  'AGNES': 37,
#  'GREY': 120,
#  '"RASETSU.': 4,
#  'VOL.': 945,
#  '9': 271,
#  'CHIKA': 9,
#  'SHIOMI': 5,
#  '"WRITING': 18,
#  'ON': 5858,
#  'WALL': 259,
#  '[SOCIAL': 2,
#  'MEDIA': 1069,
#  'MAX': 334,
#  'RUBY.': 18,
#  'SILLY': 58,
#  'BUNNY': 135,
#  'TALES.': 44,
#  'DREAMS': 402,
#  'SHADOWS:': 87,
#  'FUTURE': 432,
#  'MIDDLE': 231,
#  'EAST': 210,
#  '(UNABRIDGED)': 4691,
#  '"BREW': 4,
#  'BETTER': 423,
#  'BEER:': 6,
#  'LEARN': 307,
#  '(AND': 230,
#  'BREAK)': 4,
#  'RULES': 366,
#  'FOR': 13169,
#  'MAKING': 787,
#  'IPAS': 4,
#  '"SAUCES': 2,
#  'SHAPES': 57,
#  'PASTA': 25,
#  'ITALIAN': 295,
#  'WAY': 1319,
#  'ORETTA': 2,
#  'ZANINI': 2,
#  'VITA': 12,
#  '"ROBERT': 44,
#  'B.': 794,
#  "PARKER'S": 71,
#  'BLIND': 135,
#  'SPOT:': 11,
#  'JESSE': 140,
#  'STONE': 466,
#  '"CHICKEN': 24,
#  'SOUP': 104,
#  'SOUL.': 19,
#  'DID': 148,
#  'WHAT?': 13,
#  '101': 242,
#  'AMAZING': 419,
#  'STORIES': 2654,
#  'MAGICAL': 163,
#  'MOMENTS': 86,
#  'RESILIENCE': 25,
#  'FACTOR:': 14,
#  '7': 411,
#  'ESSENTIAL': 662,
#  'SKILLS': 187,
#  'OVERCOMING': 119,
#  "LIFE'S": 110,
#  'INEVITABLE': 7,
#  'OBSTACLES': 14,
#  '"KAMISAMA': 23,
#  'KISS.': 28,
#  '19': 49,
#  'JULIETTA': 23,
#  'SUZUKI': 75,
#  '[ENGLISH': 255,
#  'TRANSLATION': 669,
#  "DRAGON'S": 81,
#  'FAT': 210,
#  'CAT': 689,
#  'FOURTH': 268,
#  'TALE': 919,
#  'DAV': 46,
#  'PILKEY.': 32,
#  'EXTERIMINATE': 1,
#  'APOSTLES': 2,
#  '"THE': 13364,
#  'TROUBLE': 277,
#  'LOVE:': 182,
#  'SEX': 359,
#  'SPY-IN-TRAINING': 2,
#  'VOYAGING': 8,
#  'STRANGE': 305,
#  'SEAS': 55,
#  'GREAT': 1786,
#  'REVOLUTION': 458,
#  'SCIENCE': 1227,
#  'DAVID': 3791,
#  'KNIGHT.': 67,
#  'BALLETS': 8,
#  'RUSSES': 6,
#  'COLONEL': 19,
#  "BASIL'S": 1,
#  'MONTE': 29,
#  'CARLO': 51,
#  'SYMPHONY': 151,
#  'NO.': 359,
#  'FROM': 7412,
#  'NEW': 3780,
#  'WORLD': 3649,
#  'CARNIVAL': 66,
#  'OVERTURE': 30,
#  'ANTONÍN': 7,
#  'DVOŘÁK.': 13,
#  'DAS': 35,
#  'BESTE': 3,
#  'VON': 223,
#  '=': 2553,
#  'VERY': 472,
#  'BEST': 2068,
#  'ROGER': 299,
#  'NORRINGTON.': 2,
#  'SHADE': 50,
#  'GARDEN': 721,
#  'CREATING': 327,
#  'LUSH': 14,
#  'OASIS': 8,
#  'AGE': 682,
#  'CLIMATE': 91,
#  'CHANGE': 561,
#  'KEN': 320,
#  'DRUSE': 3,
#  'RETHINKING': 27,
#  'NARCISSISM': 7,
#  'BAD--AND': 2,
#  'SURPRISING': 152,
#  'GOOD--ABOUT': 2,
#  'FEELING': 69,
#  'SPECIAL': 321,
#  'CRAIG': 223,
#  'MALKIN.': 4,
#  'UNSUNG': 4,
#  'HEROES': 231,
#  'ROCK': 561,
#  "'N'": 65,
#  'ROLL': 165,
#  'BIRTH': 226,
#  'WILD': 894,
#  'YEARS': 704,
#  'BEFORE': 489,
#  'ELVIS': 87,
#  'NICK': 410,
#  'TOSCHES': 1,
#  'PREFACE.': 4,
#  'AT': 3097,
#  'HOME:': 116,
#  'SHORT': 617,
#  'HISTORY': 2469,
#  'PRIVATE': 218,
#  'LIFE': 4999,
#  'COLLAR': 15,
#  'CONSERVATIVES': 14,
#  'RECOMMITTING': 1,
#  'AMERICA': 1262,
#  'THAT': 2160,
#  'WORKS': 298,
#  'RICK': 462,
#  'SANTORUM.': 2,
#  'DANZA': 6,
#  'NATSUME': 9,
#  'ONO': 12,
#  'ADAPTED': 768,
#  'MARI': 25,
#  'MORIMOTO': 3,
#  'LETTERED': 181,
#  'AARON': 257,
#  'ALEXOVICH.': 4,
#  'UNICORN': 56,
#  'UPROAR': 3,
#  'CAROLYN': 299,
#  'KEENE': 40,
#  'MACKY': 65,
#  'PAMINTUAN.': 64,
#  '"TARNISHED': 4,
#  'TORN:': 5,
#  'WITCHCRAFT': 29,
#  'MYSTERY': 3157,
#  'FITNESS': 85,
#  'POWER': 988,
#  'SHOP': 168,
#  'CLOSET:': 5,
#  'ULTIMATE': 576,
#  'GUIDE': 5098,
#  'ORGANIZING': 38,
#  'CLOSET': 25,
#  'STYLE': 352,
#  'F1RST': 2,
#  'RECORDINGS': 93,
#  'BEATLES': 64,
#  'SHERIDAN.': 7,
#  'PANDA': 57,
#  'LAURA': 733,
#  'BULLER.': 5,
#  '"TRAVELING': 7,
#  'JOURNEY': 994,
#  'IBN': 4,
#  'BATTUTA': 2,
#  'ONE': 2611,
#  'SOUL': 444,
#  'RAY': 256,
#  'FAWKES': 2,
#  'COVER': 235,
#  'DESIGN': 691,
#  'MATT': 399,
#  'KINDT': 2,
#  'KEITH': 262,
#  'WOOD': 206,
#  'EDITED': 2680,
#  'JAMES': 2105,
#  'LUCAS': 55,
#  'JONES.': 279,
#  'COME': 344,
#  'FEEL': 196,
#  'ME': 2379,
#  'TREMBLE': 3,
#  'BARNEY': 29,
#  'MILLER.': 296,
#  'COMPLETE': 3131,
#  'SIXTH': 127,
#  'SEASON': 2915,
#  'SONY': 439,
#  'PICTURES': 5975,
#  'TELEVISION.': 631,
#  '"ANYTHING': 5,
#  'MOVES': 49,
#  'RENEGADE': 43,
#  'CHEFS': 33,
#  'UNGIFTED:': 3,
#  'INTELLIGENCE': 130,
#  'REDEFINED': 9,
#  'STREETS': 75,
#  'SAN': 232,
#  'FRANCISCO.': 16,
#  'NIGHTINGALE': 55,
#  'LENE': 20,
#  'KAABERBOL': 3,
#  'AGNETE': 12,
#  'FRIIS': 11,
#  'DANISH': 49,
#  'ELISABETH': 67,
#  'DYSSEGAARD.': 7,
#  'ROOTS': 92,
#  'BLUES': 445,
#  'AFRICAN': 214,
#  'SEARCH': 414,
#  'SAMUEL': 235,
#  'CHARTERS.': 1,
#  'STUART': 254,
#  'LITTLE': 1885,
#  'TROUBLED': 44,
#  'WATERS': 95,
#  "NONNA'S": 4,
#  'BIRTHDAY': 191,
#  'SURPRISE': 114,
#  'LIDIA': 33,
#  'BASTIANICH': 8,
#  'RENÉE': 59,
#  'GRAEF.': 16,
#  '"MINOR': 3,
#  'POSSESSION:': 7,
#  'J.': 1638,
#  'P.': 400,
#  'BEAUMONT': 71,
#  'LEO': 177,
#  'GHOST': 476,
#  'MAC': 95,
#  'BARNETT': 32,
#  'CHRISTIAN': 256,
#  'ROBINSON.': 134,
#  '"MADAGASCAR': 5,
#  'LAST': 1428,
#  'INHERITOR': 3,
#  'GONDWANA': 2,
#  'ENGLISH': 636,
#  'LANGUAGE': 386,
#  'VERSION': 117,
#  'KIP': 9,
#  'KAPLAN': 33,
#  'AUDIOWORKS': 2,
#  'PRODUCER': 1779,
#  'GROUP': 390,
#  'NYC': 17,
#  'DIRECTOR': 517,
#  'LULLABY': 181,
#  'JEWEL.': 12,
#  'SHEEP': 79,
#  'GOAT': 39,
#  'MARLEEN': 3,
#  'WESTERA': 2,
#  'ILLUSTRATIONS': 2168,
#  'SYLVIA': 105,
#  'VAN': 561,
#  'OMMEN': 2,
#  'NANCY': 702,
#  'FOREST-FLIER.': 4,
#  '"TEMPTING': 8,
#  'BRIDE:': 93,
#  'FITZHUGH': 6,
#  '"SCI-FI': 2,
#  'CHRONICLES': 618,
#  'VISUAL': 199,
#  "GALAXY'S": 4,
#  'GREATEST': 692,
#  'FICTION': 286,
#  'GENERAL': 157,
#  'EDITOR': 284,
#  'GOLDEN': 402,
#  'RING': 134,
#  '"GERMANY': 6,
#  '2': 1731,
#  'PILOT': 144,
#  'TV': 390,
#  'INFLUENCE:': 14,
#  'HOW': 5111,
#  'EXERT': 1,
#  'IT': 2018,
#  'SOME': 239,
#  'ENCHANTED': 90,
#  'EVENING': 70,
#  "MIND'S": 18,
#  'OLIVER': 227,
#  'SACKS.': 32,
#  '"FROMMER\'S': 109,
#  'EASYGUIDE': 57,
#  'WASHINGTON': 330,
#  'WICKED': 231,
#  'RISE': 460,
#  'DANIELLE': 111,
#  'PAIGE.': 14,
#  'MAMMOTHS': 4,
#  'GIANTS': 73,
#  'ADRIAN': 108,
#  'LISTER': 7,
#  'PAUL': 1559,
#  'BAHN': 2,
#  'FOREWORD': 1623,
#  'JEAN': 378,
#  'M.': 1159,
#  'AUEL.': 15,
#  'VIVALDI:': 8,
#  'GLORIA': 98,
#  '-': 621,
#  'LAUDAMUS': 1,
#  'TE': 60,
#  '"HUBRIS:': 1,
#  'INSIDE': 645,
#  'SPIN': 43,
#  'WAITING': 110,
#  'COLUMBUS': 51,
#  'FEAT.': 29,
#  'BLOOD': 593,
#  'THUNDER:': 15,
#  'EPIC': 232,
#  'KIT': 64,
#  'CARSON': 79,
#  'CONQUEST': 41,
#  'AMERICAN': 2491,
#  'WEST': 516,
#  'MADWOMAN': 11,
#  'VOLVO:': 2,
#  'YEAR': 788,
#  'RAGING': 19,
#  'HORMONES': 15,
#  'LION': 192,
#  'KING': 829,
#  'RECORDING].': 2466,
#  'END': 632,
#  'OVEREATING': 6,
#  'TAKING': 179,
#  'CONTROL': 201,
#  'INSATIABLE': 14,
#  'APPETITE': 32,
#  'A.': 1288,
#  'KESSLER.': 15,
#  'THIS': 1187,
#  'MOMENT': 93,
#  'STUBBORN': 6,
#  'WOLF': 348,
#  'CHEERS.': 7,
#  '10': 497,
#  'CBS': 263,
#  'STUDIOS': 576,
#  'PARAMOUNT': 665,
#  'PRESIDENT': 137,
#  'GAS': 22,
#  'EVAN': 75,
#  'HELP': 355,
#  'US': 598,
#  'RHYS': 53,
#  'BOWEN.': 81,
#  'SKY': 456,
#  'SCRAPERS': 1,
#  'ANDRES': 6,
#  'LEPIK.': 1,
#  'PIKE': 29,
#  'PLACE': 398,
#  'PUBLIC': 241,
#  'MARKET': 235,
#  'SEAFOOD': 19,
#  'COOKBOOK': 647,
#  'EMBRACE': 32,
#  'CONQUER': 41,
#  'INTUITION': 21,
#  'UNO': 6,
#  'DOS': 27,
#  'TRES': 21,
#  'POSADA': 3,
#  "LET'S": 226,
#  'CELEBRATE': 59,
#  'CHRISTMAS': 873,
#  'VIRGINIA': 154,
#  'KROLL': 19,
#  'LORETTA': 39,
#  'LOPEZ.': 15,
#  'BONE': 225,
#  'TREE:': 24,
#  'PENN': 34,
#  'CAGE': 55,
#  'TOO': 419,
#  'MUCH': 202,
#  'KISSING!': 2,
#  'OTHER': 1728,
#  'DILLY': 11,
#  'SONGS': 735,
#  'PARENTS': 171,
#  'ALAN': 670,
#  'KATZ': 42,
#  'CATROW.': 29,
#  'PAWNEE': 2,
#  'INDIANS.': 2,
#  'GO': 693,
#  'FLY': 230,
#  'KITE': 32,
#  'BEN': 486,
#  'KWELLER.': 2,
#  'WHISKEY': 37,
#  '"READ': 8,
#  'ALONG': 96,
#  'DVD': 90,
#  'EXECUTIVE': 893,
#  '"ETERNITY\'S': 4,
#  'WHEEL:': 4,
#  'INTERWORLD': 9,
#  'I': 3772,
#  'WOULD': 100,
#  'HAVE': 609,
#  'WAITED': 1,
#  'FOREVER': 326,
#  '"TRANSPORTER': 2,
#  'EUROPA': 22,
#  'CORP.': 70,
#  'TF1': 25,
#  'FILMS': 4468,
#  'CURRENT': 19,
#  'SEA': 840,
#  'SIDE': 349,
#  'FLORIDA': 34,
#  '"RAISING': 34,
#  'CUBBY': 4,
#  'FATHER': 211,
#  "SON'S": 31,
#  'ADVENTURES': 1012,
#  "ASPERGER'S": 30,
#  '"KNOW': 3,
#  'POSSIBILITY': 20,
#  'PROJECT': 260,
#  'MARCUS': 123,
#  'CLARKE': 33,
#  '"POLYMER': 4,
#  'CLAY': 94,
#  '30': 209,
#  'TERRIFIC': 8,
#  'PROJECTS': 638,
#  'LIVE': 859,
#  'TEN': 321,
#  'EASY': 731,
#  'STEP-BY': 1,
#  'STEP': 162,
#  'LESSONS': 403,
#  'BROTHERHOOD': 71,
#  'FEAR': 258,
#  'WILLI': 4,
#  'KRAUS': 13,
#  'DIGGER.': 3,
#  '[BY': 128,
#  'URSULA': 83,
#  'VERNON].': 3,
#  'COMMANDER.': 3,
#  'SET': 279,
#  'LYNDA': 54,
#  'LA': 1199,
#  'PLANTE': 19,
#  'WHYTE': 4,
#  '"DOWNHILL': 1,
#  'ALL': 1918,
#  'WAY:': 75,
#  'AUTOBIOGRAPHY': 186,
#  '1919-1939': 1,
#  'VAGRANTS': 1,
#  'YIYUN': 3,
#  'LI.': 14,
#  'DARK': 1063,
#  'LADY': 597,
#  "IT'S": 451,
#  'THANKSGIVING!': 1,
#  'JACK': 925,
#  'PRELUTSKY': 35,
#  'MARYLIN': 7,
#  'HAFNER.': 8,
#  'RUFF!': 2,
#  'WONDERFULLY': 3,
#  'BUSY': 85,
#  'DAY': 1603,
#  'CAROLINE': 235,
#  'JAYNE': 51,
#  'CHURCH': 92,
#  'TEXT': 562,
#  'GILLIAN': 83,
#  'SHIELDS.': 19,
#  'RECIPE': 73,
#  'BEDTIME': 99,
#  'PETER': 1750,
#  'BENTLY': 13,
#  'SARAH': 864,
#  'MASSINI.': 7,
#  'GIRL': 1193,
#  'WHO': 1920,
#  'HEARD': 55,
#  'COLORS': 305,
#  'MARIE': 236,
#  'HARRIS': 123,
#  'VANESSA': 78,
#  'BRANTLEY-NEWTON.': 7,
#  'SHOWCASE': 15,
#  '500': 94,
#  'BEADED': 15,
#  'JEWELRY': 132,
#  'BEAUTIFUL': 576,
#  'CONTEMPORARY': 212,
#  'BEADWORK': 10,
#  'HEMACHANDRA.': 1,
#  'INTRODUCING': 48,
#  'SUNNY': 70,
#  'JOY': 381,
#  'BOYS': 420,
#  'TALISMANS': 2,
#  'SHANNARA:': 15,
#  'HERITAGE': 66,
#  'SHANNARA': 34,
#  'NOT': 1010,
#  'MONEY': 530,
#  'UNLOCK': 36,
#  'ACHIEVE': 54,
#  'SPIRITUAL': 241,
#  'FINANCIAL': 210,
#  'ABUNDANCE': 37,
#  'BRENT': 63,
#  'KESSEL.': 4,
#  'MONTEZUMA': 2,
#  'FALL': 491,
#  'AZTECS': 8,
#  'ERIC': 708,
#  'KIMMEL': 81,
#  'DANIEL': 800,
#  'SOUCI.': 13,
#  'WITHOUT': 553,
#  'MAGNUM': 11,
#  'P.I.': 9,
#  'UNIVERSAL': 849,
#  'TV.': 18,
#  'INTRODUCTION': 1867,
#  'TO...': 9,
#  'MOZART:': 8,
#  'MARRIAGE': 256,
#  'FIGARO': 11,
#  'ADJACENT': 7,
#  'GLUE': 13,
#  'IRVINE': 12,
#  'WELSH.': 9,
#  'HORRIBLE': 41,
#  'HARRY': 464,
#  'TOP-SECRET': 4,
#  'HIDEOUT': 7,
#  'SUZY': 34,
#  'KLINE': 16,
#  'AMY': 566,
#  'WUMMER.': 24,
#  '"BIZZBILLA': 2,
#  'HITS': 401,
#  'BULLSEYE:': 2,
#  'ARIOL': 4,
#  'GRAPHIC': 293,
#  'ROCKY': 38,
#  'RIDGE': 38,
#  'LEA': 29,
#  'MACBRIDE': 11,
#  'GILLEECE.': 8,
#  'DINNER': 83,
#  'HERMAN': 95,
#  'KOCH': 32,
#  'DUTCH': 68,
#  'SAM': 403,
#  'GARRETT.': 28,
#  '"NISSAN': 1,
#  'SENTRA': 1,
#  '200SX': 1,
#  'AUTOMOTIVE': 20,
#  'REPAIR': 78,
#  'MANUAL': 251,
#  'LARRY': 311,
#  'WARREN': 173,
#  '"SCOURGE': 2,
#  'BETRAYER:': 2,
#  "BLOODSOUNDER'S": 2,
#  'ARC': 51,
#  'SWING': 44,
#  '"DIPLOMATIE': 2,
#  'DIPLOMACY': 8,
#  'ZEITGEIST': 30,
#  'UNE': 240,
#  'OBLIGE': 2,
#  'STAGE': 132,
#  'REBECCA': 370,
#  'PIATT': 2,
#  'DAVIDSON': 40,
#  'ANITA': 180,
#  'LOBEL.': 36,
#  '"FRESH': 18,
#  'FRUIT': 77,
#  'EAT': 388,
#  'HOMEWORK': 33,
#  'INQUIRING': 4,
#  'MINDS': 106,
#  'ANN': 728,
#  'MCCALLUM': 5,
#  'LEEZA': 6,
#  'HERNANDEZ.': 26,
#  'BROKEN': 269,
#  'LYNNE': 132,
#  'RAE': 48,
#  'PERKINS.': 29,
#  '"LEAVE': 9,
#  'MESSAGE': 49,
#  'WILLIE:': 3,
#  'SHARON': 221,
#  'MCCONE': 29,
#  'SECRETS': 890,
#  'OUT!': 23,
#  'JULIE': 458,
#  'STERNBERG': 11,
#  'JOHANNA': 49,
#  'WRIGHT.': 104,
#  'FIGHTERS': 23,
#  'LINDA': 503,
#  'SUE': 376,
#  'PARK': 368,
#  'DECORATIONS': 25,
#  'EUNG': 2,
#  'WON': 48,
#  'PARK.': 73,
#  'LOS': 289,
#  'ALAMOS': 4,
#  'MICE': 53,
#  'EMBERLEY': 11,
#  'ED': 286,
#  'EMBERLEY.': 23,
#  '"CORALINE': 6,
#  'BASED': 389,
#  'NEIL': 369,
#  'GAIMAN': 59,
#  'RUSSELL': 279,
#  'COLORIST': 9,
#  'SO': 485,
#  'SERENE': 8,
#  'JAPANESE': 355,
#  'MIND': 661,
#  'CULTURE': 303,
#  'DAVIES': 85,
#  'OSAMU': 24,
#  'IKENO.': 1,
#  'SMART': 229,
#  'DECISIONS.': 3,
#  'JOHN': 4039,
#  'COLTRANE.': 18,
#  'POLICE': 66,
#  '"GIN': 4,
#  'TAMA.': 4,
#  '11': 142,
#  '"HAVANA': 10,
#  'STORM:': 72,
#  'DIRK': 61,
#  'PITT': 59,
#  '"OH': 57,
#  "FRACTION'S": 2,
#  'GOAL:': 2,
#  'PARTS': 93,
#  'WHOLE': 230,
#  'STARS': 325,
#  'PLANETS': 38,
#  'CAROLE': 73,
#  'STOTT': 9,
#  '[ILLUSTRATIONS': 246,
#  'BULL': 50,
#  'STUDIO].': 10,
#  'NEUROSIS': 2,
#  'HUMAN': 480,
#  'GROWTH': 66,
#  'STRUGGLE': 141,
#  'TOWARD': 60,
#  'SELF-REALIZATION': 2,
#  'KAREN': 556,
#  'HORNEY.': 1,
#  '"ABOUT': 17,
#  'NIGHT--': 3,
#  'TRI-STAR': 15,
#  '12': 217,
#  'STEPS': 264,
#  'RAW': 72,
#  'FOODS:': 8,
#  'DEPENDENCY': 4,
#  'COOKED': 14,
#  'FOOD': 936,
#  '"MELTING': 3,
#  'STONES:': 19,
#  'CIRCLE': 200,
#  'REFORGED': 13,
#  '"FROM': 59,
#  'INDIA': 168,
#  'OVER': 681,
#  '100': 634,
#  'AUGIE': 6,
#  ...}

# %%
'''
Una vez terminado el Map, definimos el Reduce
'''

# generamos un diccionario que concentrara los resultados reducidos
reduced = {}

# iteramos cada elemento del mapper
for i in res:
  # recorremos a traves de las llaves
  for key in i.keys():
    # si no existe, entonces la creamos con el primer valor que encuentra 
    #   para esa llave
    if key not in reduced.keys():
      reduced[key] = i[key]
    # si existe, entonces sumamos los valores
    else:
      reduced[key] = reduced[key] + i[key]

# %%
'''
observamos el total de llaves concentradas en cada parte del mapper
'''
for i in range(len(res)):
  print('Total de llaves en la parte {}: {}'.format(i+1,len(res[i].keys())))
# Out:
# Total de llaves en la parte 1: 153758
# Total de llaves en la parte 2: 156178
# Total de llaves en la parte 3: 156310
# Total de llaves en la parte 4: 155134

# %%
# observamos el numero total de llaves reducidas
print('Total de Llaves reducidas: {}'.format(len(reduced.keys())))
# Out:
# Total de Llaves reducidas: 227903

# %%
# visualizamos las llaves (diferentes) reducidas
reduced.keys()
# Out:
# dict_keys(['TITLE', '"EMBRACING', 'LOVE.', 'VOLUME', '3', '&', '4', '/', 'STORY', 'AND', 'ART', 'BY', 'YOUKA', 'NITTA', ';', '[TRANSLATION', 'PENNY', 'HER', 'DOLL', 'POSSESSION', ':', 'A', 'ROMANCE', 'A.S.', 'BYATT.', 'BOSTON', '"MUY', 'BUENO', 'THREE', 'GENERATIONS', 'OF', 'AUTHENTIC', 'MEXICAN', 'FLAVOR', 'RECIPES', 'QB', 'BLITZ', '[TEXT', 'WRITTEN', 'STEPHANIE', 'PETERS].', 'MY', 'LEAD', 'DOG', 'WAS', 'LESBIAN:', 'MUSHING', 'ACROSS', 'ALASKA', 'IN', 'THE', 'IDITAROD—THE', "WORLD'S", 'MOST', 'GRUELING', 'RACE', '"BARRIO', 'CUBA', '[VIDEORECORDING]', 'LAGUNA', 'PRODUCTIONS', 'PRESENTS', 'AN', 'ICAIC/FINE', '"QUADRIVIUM', 'FOUR', 'CLASSICAL', 'LIBERAL', 'ARTS', 'NUMBER', 'MORE', 'ABOUT', 'PADDINGTON', '[SOUND', 'RECORDING]', 'MICHAEL', 'BOND.', 'MIDNIGHT', 'THIEF', 'LIVIA', 'BLACKBURNE.', 'DEATH', 'CAESAR', "HISTORY'S", 'FAMOUS', 'ASSASSINATION', 'BARRY', 'STRAUSS.', 'TRUE', 'BLUE', 'SCOUTS', 'SUGAR', 'MAN', 'SWAMP', 'KATHI', 'APPELT.', 'RAIN', 'SHADOW.', 'SERIES', '1', 'CREATED', 'TONY', 'MORPHETT', 'JIMMY', 'THOMSON', 'PRODUCED', 'GUS', 'HOWARD', 'DIRECTED', 'SHAWN', 'SEET', 'FIONA', 'BANKS', 'AUSTRALIAN', 'BROADCASTING', 'CORPORATION', 'FILM', 'FINANCE', 'AUSTRALIA', 'LTD', 'SOUTHERN', 'STAR', 'ENTERTAINMENT', 'PRODUCTION', 'ASSOCIATION', 'WITH', 'SOUTH', 'CORPORATION.', '"MAGIC', 'EYE', 'BEYOND', '3D', 'IMPROVE', 'YOUR', 'VISION', 'MAGIC', 'INC.', 'MARC', 'GROSSMAN', '[WRITERS', 'WHY', 'HIM?', 'HER?:', 'FINDING', 'REAL', 'LOVE', 'UNDERSTANDING', 'PERSONALITY', 'TYPE', 'DAWN', 'LAND', 'JOSEPH', 'BRUCHAC', 'ADAPTATION', 'WILL', 'DAVIS.', 'NO', 'FLYING', 'HOUSE', 'BETTY', 'BROCK', 'ILLUSTRATED', 'WALLACE', 'TRIPP.', 'ARCO', 'IRIS', 'DE', 'POESÍA', 'POEMAS', 'LAS', 'AMÉRICAS', 'Y', 'ESPAÑA', 'SELECCIÓN', 'SERGIO', 'ANDRICAÍN', 'ILUSTRADO', 'POR', 'OLGA', 'CUÉLLAR.', '¿PUEDE', 'VOLAR', 'UN', 'CANGREJO?', 'TEXTOS', 'FLORENCIA', 'ESSES', 'GRACIELA', 'REPÚN', 'ILUSTRACIONES', 'JAVIER', 'PEÑA.', 'TRAUMA', 'PLAN', 'CANDACE', 'CALVERT.', 'SUPREME', 'MACARONI', 'COMPANY', '[A', 'NOVEL]', 'ADRIANA', 'TRIGIANI.', 'LE', 'PETIT', 'PRINCE', 'ANTOINE', 'SAINT-EXUPÉRY', 'AVEC', 'DES', 'AQUARELLES', "L'AUTEUR.", '"CONSENT', 'TO', 'KILL:', 'MITCH', 'RAPP', 'EVERY', 'BREATH', 'YOU', 'TAKE:', 'NOVEL', '"ENERGY', 'EXPERIMENTS', 'USING', 'ICE', 'CUBES', 'CRUMB', 'BAKING', 'BOOK', 'RUBY', 'TANDOH', 'PHOTOGRAPHS', 'NATO', 'WELTON.', 'METERS', 'ANTHOLOGY', 'FUNKIFY', 'LIFE.', 'DON', 'QUIXOTE', 'MIGUEL', 'CERVANTES', 'TRANSLATED', 'EDITH', 'GROSSMAN.', 'WOUNDED', 'THORN', 'FAY', 'SAMPSON.', 'DISARMING', 'NARCISSIST', 'SURVIVING', 'THRIVING', 'SELF-ABSORBED', 'WENDY', 'T.', 'BEHARY.', '"NATSUME\'S', 'FRIENDS.', 'YUKI', 'MIDORIKAWA', 'AGNES', 'GREY', '"RASETSU.', 'VOL.', '9', 'CHIKA', 'SHIOMI', '"WRITING', 'ON', 'WALL', '[SOCIAL', 'MEDIA', 'MAX', 'RUBY.', 'SILLY', 'BUNNY', 'TALES.', 'DREAMS', 'SHADOWS:', 'FUTURE', 'MIDDLE', 'EAST', '(UNABRIDGED)', '"BREW', 'BETTER', 'BEER:', 'LEARN', '(AND', 'BREAK)', 'RULES', 'FOR', 'MAKING', 'IPAS', '"SAUCES', 'SHAPES', 'PASTA', 'ITALIAN', 'WAY', 'ORETTA', 'ZANINI', 'VITA', '"ROBERT', 'B.', "PARKER'S", 'BLIND', 'SPOT:', 'JESSE', 'STONE', '"CHICKEN', 'SOUP', 'SOUL.', 'DID', 'WHAT?', '101', 'AMAZING', 'STORIES', 'MAGICAL', 'MOMENTS', 'RESILIENCE', 'FACTOR:', '7', 'ESSENTIAL', 'SKILLS', 'OVERCOMING', "LIFE'S", 'INEVITABLE', 'OBSTACLES', '"KAMISAMA', 'KISS.', '19', 'JULIETTA', 'SUZUKI', '[ENGLISH', 'TRANSLATION', "DRAGON'S", 'FAT', 'CAT', 'FOURTH', 'TALE', 'DAV', 'PILKEY.', 'EXTERIMINATE', 'APOSTLES', '"THE', 'TROUBLE', 'LOVE:', 'SEX', 'SPY-IN-TRAINING', 'VOYAGING', 'STRANGE', 'SEAS', 'GREAT', 'REVOLUTION', 'SCIENCE', 'DAVID', 'KNIGHT.', 'BALLETS', 'RUSSES', 'COLONEL', "BASIL'S", 'MONTE', 'CARLO', 'SYMPHONY', 'NO.', 'FROM', 'NEW', 'WORLD', 'CARNIVAL', 'OVERTURE', 'ANTONÍN', 'DVOŘÁK.', 'DAS', 'BESTE', 'VON', '=', 'VERY', 'BEST', 'ROGER', 'NORRINGTON.', 'SHADE', 'GARDEN', 'CREATING', 'LUSH', 'OASIS', 'AGE', 'CLIMATE', 'CHANGE', 'KEN', 'DRUSE', 'RETHINKING', 'NARCISSISM', 'BAD--AND', 'SURPRISING', 'GOOD--ABOUT', 'FEELING', ' ...

# %%
'''
Podemos visualizar el conteo de cada llave/palabra tanto en el total, despues
de la reduccion, como en cada una de las partes antes de ser reducida
'''

desired_word = 'AMERICAN'

desired_word_counter_after_reduce = 0

print('La palabra {} aparece un numero total de {}'.format(desired_word,reduced[desired_word]))
for i in range(len(res)):
  print('{} aparece {} veces en la parte {}'.format(desired_word,res[i][desired_word],i+1))
  desired_word_counter_after_reduce += res[i][desired_word]
# Out:
# La palabra AMERICAN aparece un numero total de 9760
# AMERICAN aparece 2491 veces en la parte 1
# AMERICAN aparece 2390 veces en la parte 2
# AMERICAN aparece 2490 veces en la parte 3
# AMERICAN aparece 2389 veces en la parte 4
